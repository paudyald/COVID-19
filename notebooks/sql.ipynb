# %% [markdown]
# # Labour force characteristics by immigrant status data

# %% [markdown]
# ## Data Source
# - Statistics Canada,
# - Immigration and ethnocultural diversity.
# - Labour force characteristics by immigrant status
# - DOI:    https://doi.org/10.25318/1410008201-eng

# %% [markdown]
# # SQL, MySQL and SQLite

# %% [markdown]
# #### SQL (Structured Query Language) is a server-based query language that is used to query database.

# %% [markdown]
# -  It is a database system used on the web, and  runs on a server

# %% [markdown]
# -  It allows users to access data stored in a Relational Database Management System (RDMS), and it also aloows us to create, delete databases and sets permissions on database tables, views and procedures.

# %% [markdown]
# #### MySQL is a client-based query language  that uses standard  SQL to manage data,  it has a User Interface (UI)

# %% [markdown]
# - It is a database system used on the web that  runs on a server and stores data in tables

# %% [markdown]
# - It is ideal for both small and large applications, including data warehousing, e-commerce, and logging applications. It compiles on a number of platforms and the most common use of MySQL is for the purpose of a web database.

# %% [markdown]
# #### SQLite is a  file-based query language that uses MySQL to manage data.

# %% [markdown]
# - SQLite is an embedded SQL database engine. Unlike most other SQL databases, SQLite does not have a separate server process.

# %% [markdown]
# - It is used in mobile device as a database for local storage.

# %% [markdown]
# ## Some SQL commands

# %% [markdown]
# - SELECT
# - WHERE
# - LIMIT
# - ORDER BY
# - GROUP BY
# - INSERT
# - UPDATE
# - DELETE
# - AND
# - OR
# - MIN
# - MAX
# - AVG
# - SUM
# - COUNT

# %% [markdown]
# ## Import SQLite

# %%
import sqlite3 as lite
import pandas as pd
from pandas.io import sql

# %% [markdown]
# ### Connect to the SQL database

# %%
db = lite.connect('sqldata.db')

# %%
db

# %% [markdown]
# ### Define a fucntion that will output any type of query

# %% [markdown]
# - We'll define a function that takes our query (stored as a string) as an input and shows the result as a formatted dataframe:

# %%
def sql_query(query):
    return pd.read_sql_query(query,db)

# %% [markdown]
# # SELECT column-names  FROM table

# %% [markdown]
# - **SELECT** is the foundation of almost every query.
# - It tells the database which columns we want to see.
# - We can either specify columns by name (separated by commas) or use the wildcard * to return every column in the table.

# %% [markdown]
# - In this example, we use **SELECT** command and told the database  we are interested in  **Agegroup** and **VALUE** columns. We also used **FROM** to let the database know that the columns we want to see are part of the **sqldata** table.

# %% [markdown]
# - **sqldata** is the name of table.

# %%
query = 'SELECT Agegroup, VALUE  FROM sqldata;'
sql_query(query)
# Out:
#                  Agegroup    VALUE
# 0       15 years and over  25977.3
# 1          25 to 54 years  14085.0
# 2       15 years and over  17128.9
# 3          25 to 54 years  12043.1
# 4       15 years and over  15948.6
# ...                   ...      ...
# 322555     25 to 54 years      3.4
# 322556  15 years and over     69.0
# 322557     25 to 54 years     89.8
# 322558  15 years and over     66.5
# 322559     25 to 54 years     86.8
#
# [322560 rows x 2 columns]

# %% [markdown]
# - We certainly don't need to display all the rows, therefore we limit the number of rows.

# %% [markdown]
# - In this example, we  used **LIMIT**  to our query to display  the first five rows in the database.

# %%
query = 'SELECT Agegroup, VALUE  FROM sqldata LIMIT 5;'
sql_query(query)
# Out:
#             Agegroup    VALUE
# 0  15 years and over  25977.3
# 1     25 to 54 years  14085.0
# 2  15 years and over  17128.9
# 3     25 to 54 years  12043.1
# 4  15 years and over  15948.6

# %% [markdown]
# # SELECT  * to return every column FROM table

# %% [markdown]
# -  In this example, we use the wildcard * to return every column in the table, **sqldata**.

# %%
query = 'SELECT * FROM sqldata LIMIT 20;'
sql_query(query)
# Out:
#    REF_DATE     GEO           DGUID   Immigrantstatus  \
# 0   2006-03  Canada  2016A000011124  Total population
# 1   2006-03  Canada  2016A000011124  Total population
# 2   2006-03  Canada  2016A000011124  Total population
# 3   2006-03  Canada  2016A000011124  Total population
# 4   2006-03  Canada  2016A000011124  Total population
# 5   2006-03  Canada  2016A000011124  Total population
# 6   2006-03  Canada  2016A000011124  Total population
# 7   2006-03  Canada  2016A000011124  Total population
# 8   2006-03  Canada  2016A000011124  Total population
# 9   2006-03  Canada  2016A000011124  Total population
# 10  2006-03  Canada  2016A000011124  Total population
# 11  2006-03  Canada  2016A000011124  Total population
# 12  2006-03  Canada  2016A000011124  Total population
# 13  2006-03  Canada  2016A000011124  Total population
# 14  2006-03  Canada  2016A000011124  Total population
# 15  2006-03  Canada  2016A000011124  Total population
# 16  2006-03  Canada  2016A000011124  Total population
# 17  2006-03  Canada  2016A000011124  Total population
# 18  2006-03  Canada  2016A000011124  Total population
# 19  2006-03  Canada  2016A000011124  Total population
#
#    Labourforcecharacteristics           Agegroup         UOM  UOM_ID  \
# 0                  Population  15 years and over     Persons     249
# 1                  Population     25 to 54 years     Persons     249
# 2                Labour force  15 years and over     Persons     249
# 3                Labour force     25 to 54 years     Persons     249
# 4                  Employment  15 years and over     Persons     249
# 5                  Employment     25 to 54 years     Persons     249
# 6        Full-time employment  15 years and over     Persons     249
# 7        Full-time employment     25 to 54 years     Persons     249
# 8        Part-time employment  15 years and over     Persons     249
# 9        Part-time employment     25 to 54 years     Persons     249
# 10               Unemployment  15 years and over     Persons     249
# 11               Unemployment     25 to 54 years     Persons     249
# 12        Not in labour force  15 years and over     Persons     249
# 13        Not in labour force     25 to 54 years     Persons     249
# 14          Unemployment rate  15 years and over  Percentage     242
# 15          Unemployment rate     25 to 54 years  Percentage     242
# 16         Participation rate  15 years and over  Percentage     242
# 17         Participation rate     25 to 54 years  Percentage     242
# 18            Employment rate  15 years and over  Percentage     242
# 19            Employment rate     25 to 54 years  Percentage     242
#
#    SCALAR_FACTOR  SCALAR_ID     VECTOR COORDINATE    VALUE STATUS SYMBOL  \
# 0      thousands          3  v53035496    1.1.1.1  25977.3   None   None
# 1      thousands          3  v53035497    1.1.1.2  14085.0   None   None
# 2      thousands          3  v53035498    1.1.2.1  17128.9   None   None
# 3      thousands          3  v53035499    1.1.2.2  12043.1   None   None
# 4      thousands          3  v53035500    1.1.3.1  15948.6   None   None
# 5      thousands          3  v53035501    1.1.3.2  11325.8   None   None
# 6      thousands          3  v53035502    1.1.4.1  12823.5   None   None
# 7      thousands          3  v53035503    1.1.4.2   9926.0   None   None
# 8      thousands          3  v53035504    1.1.5.1   3125.1   None   None
# 9      thousands          3  v53035505    1.1.5.2   1399.9   None   None
# 10     thousands          3  v53035506    1.1.6.1   1180.3   None   None
# 11     thousands          3  v53035507    1.1.6.2    717.3   None   None
# 12     thousands          3  v53035508    1.1.7.1   8848.5   None   None
# 13     thousands          3  v53035509    1.1.7.2   2041.8   None   None
# 14         units          0  v53035510    1.1.8.1      6.9   None   None
# 15         units          0  v53035511    1.1.8.2      6.0   None   None
# 16         units          0  v53035512    1.1.9.1     65.9   None   None
# 17         units          0  v53035513    1.1.9.2     85.5   None   None
# 18         units          0  v53035514   1.1.10.1     61.4   None   None
# 19         units          0  v53035515   1.1.10.2     80.4   None   None
#
#    TERMINATED  DECIMALS
# 0        None         1
# 1        None         1
# 2        None         1
# 3        None         1
# 4        None         1
# 5        None         1
# 6        None         1
# 7        None         1
# 8        None         1
# 9        None         1
# 10       None         1
# 11       None         1
# 12       None         1
# 13       None         1
# 14       None         1
# 15       None         1
# 16       None         1
# 17       None         1
# 18       None         1
# 19       None         1

# %% [markdown]
# # ORDER BY  to sort-order

# %% [markdown]
# - We use the **ORDER BY** to sort the database on a given column.

# %% [markdown]
# - By default, **ORDER BY** sorts in ascending order. If we would like to specify which order the database should be sorted, we can add the keyword **ASC** for ascending order or **DESC** for descending order.

# %% [markdown]
# - In this example, we use **SELECT** command and told the database  we are interested in  **VALUE** columns.
#
#
# - We also used **FROM** to let the database know that the columns we want to see are part of the **sqldata** table.
#
#
# - Then, we used **ORDER BY** command to sort the **VALUE** column in descending order.
#
#
# - We also used  **LIMIT** to our query to display the first five rows in the database.

# %%
query = '''
SELECT VALUE FROM sqldata
ORDER BY VALUE DESC
LIMIT 5;
'''
sql_query(query)
# Out:
#      VALUE
# 0  30995.9
# 1  30964.3
# 2  30931.2
# 3  30894.6
# 4  30851.6

# %% [markdown]
# # WHERE condition

# %% [markdown]
# - We use the **WHERE** to select or specify the  rows.

# %% [markdown]
# - In the following example, we use  **WHERE** command to return the GEO **Saskatchewan**

# %%
query = '''
SELECT * FROM sqldata
WHERE GEO = "Saskatchewan";
'''
sql_query(query)
# Out:
#       REF_DATE           GEO        DGUID   Immigrantstatus  \
# 0      2006-03  Saskatchewan  2016A000247  Total population
# 1      2006-03  Saskatchewan  2016A000247  Total population
# 2      2006-03  Saskatchewan  2016A000247  Total population
# 3      2006-03  Saskatchewan  2016A000247  Total population
# 4      2006-03  Saskatchewan  2016A000247  Total population
# ...        ...           ...          ...               ...
# 20155  2020-02  Saskatchewan  2016A000247    Born in Canada
# 20156  2020-02  Saskatchewan  2016A000247    Born in Canada
# 20157  2020-02  Saskatchewan  2016A000247    Born in Canada
# 20158  2020-02  Saskatchewan  2016A000247    Born in Canada
# 20159  2020-02  Saskatchewan  2016A000247    Born in Canada
#
#       Labourforcecharacteristics           Agegroup         UOM  UOM_ID  \
# 0                     Population  15 years and over     Persons     249
# 1                     Population     25 to 54 years     Persons     249
# 2                   Labour force  15 years and over     Persons     249
# 3                   Labour force     25 to 54 years     Persons     249
# 4                     Employment  15 years and over     Persons     249
# ...                          ...                ...         ...     ...
# 20155          Unemployment rate     25 to 54 years  Percentage     242
# 20156         Participation rate  15 years and over  Percentage     242
# 20157         Participation rate     25 to 54 years  Percentage     242
# 20158            Employment rate  15 years and over  Percentage     242
# 20159            Employment rate     25 to 54 years  Percentage     242
#
#       SCALAR_FACTOR  SCALAR_ID     VECTOR COORDINATE  VALUE STATUS SYMBOL  \
# 0         thousands          3  v53036936   13.1.1.1  747.8   None   None
# 1         thousands          3  v53036937   13.1.1.2  377.2   None   None
# 2         thousands          3  v53036938   13.1.2.1  499.4   None   None
# 3         thousands          3  v53036939   13.1.2.2  331.8   None   None
# 4         thousands          3  v53036940   13.1.3.1  470.7   None   None
# ...             ...        ...        ...        ...    ...    ...    ...
# 20155         units          0  v53037051   13.6.8.2    4.7   None   None
# 20156         units          0  v53037052   13.6.9.1   67.3   None   None
# 20157         units          0  v53037053   13.6.9.2   88.8   None   None
# 20158         units          0  v53037054  13.6.10.1   63.5   None   None
# 20159         units          0  v53037055  13.6.10.2   84.6   None   None
#
#       TERMINATED  DECIMALS
# 0           None         1
# 1           None         1
# 2           None         1
# 3           None         1
# 4           None         1
# ...          ...       ...
# 20155       None         1
# 20156       None         1
# 20157       None         1
# 20158       None         1
# 20159       None         1
#
# [20160 rows x 17 columns]

# %% [markdown]
# - In the following example, we use  **WHERE** command to return  Agegroup **25 to 54 years**.

# %%
query = '''
SELECT * FROM sqldata
WHERE Agegroup = "25 to 54 years";
'''
sql_query(query)
# Out:
#        REF_DATE                          GEO           DGUID  \
# 0       2006-03                       Canada  2016A000011124
# 1       2006-03                       Canada  2016A000011124
# 2       2006-03                       Canada  2016A000011124
# 3       2006-03                       Canada  2016A000011124
# 4       2006-03                       Canada  2016A000011124
# ...         ...                          ...             ...
# 161275  2020-02  Vancouver, British Columbia    2011S0503933
# 161276  2020-02  Vancouver, British Columbia    2011S0503933
# 161277  2020-02  Vancouver, British Columbia    2011S0503933
# 161278  2020-02  Vancouver, British Columbia    2011S0503933
# 161279  2020-02  Vancouver, British Columbia    2011S0503933
#
#          Immigrantstatus Labourforcecharacteristics        Agegroup  \
# 0       Total population                 Population  25 to 54 years
# 1       Total population               Labour force  25 to 54 years
# 2       Total population                 Employment  25 to 54 years
# 3       Total population       Full-time employment  25 to 54 years
# 4       Total population       Part-time employment  25 to 54 years
# ...                  ...                        ...             ...
# 161275    Born in Canada               Unemployment  25 to 54 years
# 161276    Born in Canada        Not in labour force  25 to 54 years
# 161277    Born in Canada          Unemployment rate  25 to 54 years
# 161278    Born in Canada         Participation rate  25 to 54 years
# 161279    Born in Canada            Employment rate  25 to 54 years
#
#                UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID     VECTOR COORDINATE  \
# 0          Persons     249     thousands          3  v53035497    1.1.1.2
# 1          Persons     249     thousands          3  v53035499    1.1.2.2
# 2          Persons     249     thousands          3  v53035501    1.1.3.2
# 3          Persons     249     thousands          3  v53035503    1.1.4.2
# 4          Persons     249     thousands          3  v53035505    1.1.5.2
# ...            ...     ...           ...        ...        ...        ...
# 161275     Persons     249     thousands          3  v53037407   16.6.6.2
# 161276     Persons     249     thousands          3  v53037409   16.6.7.2
# 161277  Percentage     242         units          0  v53037411   16.6.8.2
# 161278  Percentage     242         units          0  v53037413   16.6.9.2
# 161279  Percentage     242         units          0  v53037415  16.6.10.2
#
#           VALUE STATUS SYMBOL TERMINATED  DECIMALS
# 0       14085.0   None   None       None         1
# 1       12043.1   None   None       None         1
# 2       11325.8   None   None       None         1
# 3        9926.0   None   None       None         1
# 4        1399.9   None   None       None         1
# ...         ...    ...    ...        ...       ...
# 161275     16.0   None   None       None         1
# 161276     52.6   None   None       None         1
# 161277      3.4   None   None       None         1
# 161278     89.8   None   None       None         1
# 161279     86.8   None   None       None         1
#
# [161280 rows x 17 columns]

# %% [markdown]
# - In this example, the query  returns the VALUE greater than **500**, and it   also has a **GEO** named **Saskatchewan**.
#
#
# - We used **AND** to specify both conditions.

# %%
query = '''
SELECT * FROM sqldata
WHERE VALUE > 500 AND GEO = "Saskatchewan"
ORDER BY VALUE DESC
LIMIT 5;
'''
sql_query(query)
# Out:
#   REF_DATE           GEO        DGUID   Immigrantstatus  \
# 0  2020-02  Saskatchewan  2016A000247  Total population
# 1  2020-01  Saskatchewan  2016A000247  Total population
# 2  2019-12  Saskatchewan  2016A000247  Total population
# 3  2019-11  Saskatchewan  2016A000247  Total population
# 4  2019-10  Saskatchewan  2016A000247  Total population
#
#   Labourforcecharacteristics           Agegroup      UOM  UOM_ID  \
# 0                 Population  15 years and over  Persons     249
# 1                 Population  15 years and over  Persons     249
# 2                 Population  15 years and over  Persons     249
# 3                 Population  15 years and over  Persons     249
# 4                 Population  15 years and over  Persons     249
#
#   SCALAR_FACTOR  SCALAR_ID     VECTOR COORDINATE  VALUE STATUS SYMBOL  \
# 0     thousands          3  v53036936   13.1.1.1  893.3   None   None
# 1     thousands          3  v53036936   13.1.1.1  893.0   None   None
# 2     thousands          3  v53036936   13.1.1.1  892.6   None   None
# 3     thousands          3  v53036936   13.1.1.1  892.0   None   None
# 4     thousands          3  v53036936   13.1.1.1  891.1   None   None
#
#   TERMINATED  DECIMALS
# 0       None         1
# 1       None         1
# 2       None         1
# 3       None         1
# 4       None         1

# %%
query = '''
SELECT * FROM sqldata
WHERE VALUE > 15000 AND GEO = "Canada" AND Labourforcecharacteristics = "Full-time employment"
ORDER BY VALUE DESC
LIMIT 5;
'''
sql_query(query)
# Out:
#   REF_DATE     GEO           DGUID   Immigrantstatus  \
# 0  2019-08  Canada  2016A000011124  Total population
# 1  2019-09  Canada  2016A000011124  Total population
# 2  2019-07  Canada  2016A000011124  Total population
# 3  2019-10  Canada  2016A000011124  Total population
# 4  2018-08  Canada  2016A000011124  Total population
#
#   Labourforcecharacteristics           Agegroup      UOM  UOM_ID  \
# 0       Full-time employment  15 years and over  Persons     249
# 1       Full-time employment  15 years and over  Persons     249
# 2       Full-time employment  15 years and over  Persons     249
# 3       Full-time employment  15 years and over  Persons     249
# 4       Full-time employment  15 years and over  Persons     249
#
#   SCALAR_FACTOR  SCALAR_ID     VECTOR COORDINATE    VALUE STATUS SYMBOL  \
# 0     thousands          3  v53035502    1.1.4.1  15980.9   None   None
# 1     thousands          3  v53035502    1.1.4.1  15894.5   None   None
# 2     thousands          3  v53035502    1.1.4.1  15841.8   None   None
# 3     thousands          3  v53035502    1.1.4.1  15728.5   None   None
# 4     thousands          3  v53035502    1.1.4.1  15678.4   None   None
#
#   TERMINATED  DECIMALS
# 0       None         1
# 1       None         1
# 2       None         1
# 3       None         1
# 4       None         1

# %% [markdown]
# # Aggregate Functions

# %% [markdown]
# - We can use **COUNT, SUM, AVG, MIN and MAX** to return the rows, sum, average, minimum and maximum of a column respectively. These functions are known as aggregate functions.

# %% [markdown]
# # COUNT

# %% [markdown]
# - We can use **SELECT COUNT(*)** to count up the total number of rows returned and **WHERE** GEO = "Saskatchewan" to make sure we only take the Saskatchewan data.

# %% [markdown]
# - We can also use **COUNT(1)** or **COUNT(*)** to count up every row in our query.

# %%
query = '''
SELECT COUNT(*)FROM sqldata
WHERE GEO = "Saskatchewan";
'''
sql_query(query)
# Out:
#    COUNT(*)
# 0     20160

# %% [markdown]
# # AS to give our output an alias

# %% [markdown]
# - we can use **AS** to give our output an alias (or nickname)

# %% [markdown]
# - Let's re-run the previous query but give our column heading an alias of **New Immigrant Population in Saskatchewan**:

# %%
query = '''
SELECT COUNT(*) AS "New Immigrant Population in Saskatchewan"
FROM sqldata
WHERE GEO = "Saskatchewan";
'''
sql_query(query)
# Out:
#    New Immigrant Population in Saskatchewan
# 0                                     20160

# %% [markdown]
# # SUM, AVG, MIN and MAX

# %% [markdown]
# - In this example, the query  returns the average value, **AVG**,  of the total population from  VALUE column.

# %%
query = '''
SELECT AVG(VALUE) AS "Average Population"
FROM sqldata;
'''
sql_query(query)
# Out:
#    Average Population
# 0           457.80736

# %%
query = '''
SELECT MAX(VALUE) AS "Maximum Population"
FROM sqldata;
'''
sql_query(query)
# Out:
#    Maximum Population
# 0             30995.9

# %% [markdown]
# # GROUP BY

# %% [markdown]
# - **GROUP BY** separates rows into groups based on the contents of a particular column and allows us to perform aggregate functions on each group.

# %%
query = '''
SELECT  AVG(VALUE) AS "Average Population" 
FROM sqldata
GROUP BY GEO
LIMIT 5;
'''
sql_query(query)
# Out:
#    Average Population
# 0          330.569531
# 1          181.908789
# 2          377.197644
# 3         2722.203423
# 4          106.773764

# %% [markdown]
# - Which  Agegroup people landed to canada the most? In this example, we use **ORDER BY** clause to sort the table in descending order and make sure our Agegroup with largest VALUE is at the top.

# %%
query = '''
SELECT Agegroup as "Age Group", COUNT(*) AS "VALUE"
FROM sqldata
GROUP BY Agegroup
ORDER BY COUNT(*) DESC
LIMIT 1;
'''
sql_query(query)
# Out:
#         Age Group   VALUE
# 0  25 to 54 years  161280

# %% [markdown]
# # Arithmetic Operators

# %% [markdown]
# - SQL allows us to use +, -, * and / to perform an arithmetic operation on an entire column at once.

# %%
query = '''
SELECT AVG(VALUE) FROM sqldata
WHERE (VALUE) > 30000;
'''
sql_query(query)
# Out:
#      AVG(VALUE)
# 0  30480.485714

# %% [markdown]
# # SQL toolkit, SQLAlchemy

# %%
c= db.cursor()

# %%
from sqlalchemy import create_engine

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %load_ext sql

# %%
# %sql sqlite://
# Out:
# 'Connected: @None'

# %%
result = %sql SELECT * FROM sqldata WHERE VALUE > (SELECT AVG(VALUE) FROM sqldata)
#larger_bills = result.DataFrame()
#larger_bills.head(3)
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
#sns.lmplot(x="REF_DATE", y="VALUE", hue="GEO", data=larger_bills);
